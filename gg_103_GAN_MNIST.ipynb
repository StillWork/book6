# %% [markdown]
# <a href="https://colab.research.google.com/github/StillWork/book6/blob/master/gg_103_GAN_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Model
from keras.optimizers import Adam
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# !ls
# Out:
# sample_data

# %%
# !mkdir images

# %%
(X_train, _), (_, _) = mnist.load_data()
X_train = (X_train.astype(np.float32) - 127.5) / 127.5
X_train = np.expand_dims(X_train, axis=3)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
def build_generator(noise_shape=(100,)):
    input = Input(noise_shape)
    x = Dense(128 * 7 * 7, activation="relu")(input)
    x = Reshape((7, 7, 128))(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = UpSampling2D()(x)
    x = Conv2D(128, kernel_size=3, padding="same")(x)
    x = Activation("relu")(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = UpSampling2D()(x)
    x = Conv2D(64, kernel_size=3, padding="same")(x)
    x = Activation("relu")(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Conv2D(1, kernel_size=3, padding="same")(x)
    out = Activation("tanh")(x)
    model = Model(input, out)
    print("-- Generator -- ")
    model.summary()
    return model


def build_discriminator(img_shape):
    input = Input(img_shape)
    x =Conv2D(32, kernel_size=3, strides=2, padding="same")(input)
    x = LeakyReLU(alpha=0.2)(x)
    x = Dropout(0.25)(x)
    x = Conv2D(64, kernel_size=3, strides=2, padding="same")(x)
    x = ZeroPadding2D(padding=((0, 1), (0, 1)))(x)
    x = (LeakyReLU(alpha=0.2))(x)
    x = Dropout(0.25)(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Conv2D(128, kernel_size=3, strides=2, padding="same")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = Dropout(0.25)(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Conv2D(256, kernel_size=3, strides=1, padding="same")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = Dropout(0.25)(x)
    x = Flatten()(x)
    out = Dense(1, activation='sigmoid')(x)

    model = Model(input, out)
    print("-- Discriminator -- ")
    model.summary()
    return model


def train(generator, discriminator, combined, epochs=2000, batch_size=128, save_interval=50):

#     X_train = load_data()

    num_examples = X_train.shape[0]
    num_batches = int(num_examples / float(batch_size))
    print('Number of examples: ', num_examples)
    print('Number of Batches: ', num_batches)
    print('Number of epochs: ', epochs)

    half_batch = int(batch_size / 2)

    for epoch in range(epochs + 1):
        for batch in range(num_batches):

            # noise images for the batch
            noise = np.random.normal(0, 1, (half_batch, 100))
            fake_images = generator.predict(noise)
            fake_labels = np.zeros((half_batch, 1))

            # real images for batch
            idx = np.random.randint(0, X_train.shape[0], half_batch)
            real_images = X_train[idx]
            real_labels = np.ones((half_batch, 1))

            # Train the discriminator (real classified as ones and generated as zeros)
            d_loss_real = discriminator.train_on_batch(real_images, real_labels)
            d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            noise = np.random.normal(0, 1, (batch_size, 100))
            # Train the generator
            g_loss = combined.train_on_batch(noise, np.ones((batch_size, 1)))

            # Plot the progress
            print("Epoch %d Batch %d/%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" %
                  (epoch,batch, num_batches, d_loss[0], 100 * d_loss[1], g_loss))

            if batch % 50 == 0:
                save_imgs(generator, epoch, batch)


def save_imgs(generator, epoch, batch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, 100))
    gen_imgs = generator.predict(noise)

    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i, j].imshow(gen_imgs[cnt, :, :, 0], cmap='gray')
            axs[i, j].axis('off')
            cnt += 1
    fig.savefig("images/mnist_%d_%d.png" % (epoch, batch))
    plt.close()


def build_models():

    gen_optimizer = Adam(lr=0.0002, beta_1=0.5)
    disc_optimizer = Adam(lr=0.0002, beta_1=0.5)


    discriminator = build_discriminator(img_shape=(28, 28, 1))
    discriminator.compile(loss='binary_crossentropy',
                               optimizer=disc_optimizer,
                               metrics=['accuracy'])

    generator = build_generator()
    generator.compile(loss='binary_crossentropy', optimizer=gen_optimizer)

    z = Input(shape=(100,))
    img = generator(z)
    discriminator.trainable = False
    real = discriminator(img)
    combined = Model(z, real)
    combined.compile(loss='binary_crossentropy', optimizer=gen_optimizer)
    return generator, discriminator, combined

# %%
generator, discriminator, combined = build_models()

train(generator, discriminator, combined,
      epochs=100, batch_size=32, save_interval=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a2b8d70daad9> in <module>()
# ----> 1 generator, discriminator, combined = build_models()
#       2
#       3 train(generator, discriminator, combined,
#       4       epochs=100, batch_size=32, save_interval=1)
#
# NameError: name 'build_models' is not defined

# %%
# !ls
# Out:
# images	sample_data

# %%
# %cd images/
# Out:
# /content/images

# %%
# !ls
# Out:
# mnist_0_0.png	   mnist_16_1700.png  mnist_23_750.png	 mnist_31_250.png
# mnist_0_1000.png   mnist_16_1750.png  mnist_23_800.png	 mnist_3_1300.png
# mnist_0_100.png    mnist_16_1800.png  mnist_23_850.png	 mnist_31_300.png
# mnist_0_1050.png   mnist_16_1850.png  mnist_23_900.png	 mnist_3_1350.png
# mnist_0_1100.png   mnist_16_200.png   mnist_23_950.png	 mnist_31_350.png
# mnist_0_1150.png   mnist_16_250.png   mnist_2_400.png	 mnist_3_1400.png
# mnist_0_1200.png   mnist_16_300.png   mnist_24_0.png	 mnist_31_400.png
# mnist_0_1250.png   mnist_16_350.png   mnist_24_1000.png  mnist_3_1450.png
# mnist_0_1300.png   mnist_16_400.png   mnist_24_100.png	 mnist_31_450.png
# mnist_0_1350.png   mnist_16_450.png   mnist_24_1050.png  mnist_3_1500.png
# mnist_0_1400.png   mnist_16_500.png   mnist_24_1100.png  mnist_31_500.png
# mnist_0_1450.png   mnist_1_650.png    mnist_24_1150.png  mnist_3_150.png
# mnist_0_1500.png   mnist_16_50.png    mnist_24_1200.png  mnist_31_50.png
# mnist_0_150.png    mnist_16_550.png   mnist_24_1250.png  mnist_3_1550.png
# mnist_0_1550.png   mnist_16_600.png   mnist_24_1300.png  mnist_31_550.png
# mnist_0_1600.png   mnist_16_650.png   mnist_24_1350.png  mnist_3_1600.png
# mnist_0_1650.png   mnist_16_700.png   mnist_24_1400.png  mnist_31_600.png
# mnist_0_1700.png   mnist_16_750.png   mnist_24_1450.png  mnist_3_1650.png
# mnist_0_1750.png   mnist_16_800.png   mnist_24_1500.png  mnist_31_650.png
# mnist_0_1800.png   mnist_16_850.png   mnist_24_150.png	 mnist_3_1700.png
# mnist_0_1850.png   mnist_16_900.png   mnist_24_1550.png  mnist_31_700.png
# mnist_0_200.png    mnist_16_950.png   mnist_24_1600.png  mnist_3_1750.png
# mnist_0_250.png    mnist_1_700.png    mnist_24_1650.png  mnist_31_750.png
# mnist_0_300.png    mnist_17_0.png     mnist_24_1700.png  mnist_3_1800.png
# mnist_0_350.png    mnist_17_1000.png  mnist_24_1750.png  mnist_31_800.png
# mnist_0_400.png    mnist_17_100.png   mnist_24_1800.png  mnist_3_1850.png
# mnist_0_450.png    mnist_17_1050.png  mnist_24_1850.png  mnist_31_850.png
# mnist_0_500.png    mnist_17_1100.png  mnist_24_200.png	 mnist_31_900.png
# mnist_0_50.png	   mnist_17_1150.png  mnist_24_250.png	 mnist_31_950.png
# mnist_0_550.png    mnist_17_1200.png  mnist_24_300.png	 mnist_3_200.png
# mnist_0_600.png    mnist_17_1250.png  mnist_24_350.png	 mnist_32_0.png
# mnist_0_650.png    mnist_17_1300.png  mnist_24_400.png	 mnist_32_1000.png
# mnist_0_700.png    mnist_17_1350.png  mnist_24_450.png	 mnist_32_100.png
# mnist_0_750.png    mnist_17_1400.png  mnist_24_500.png	 mnist_32_1050.png
# mnist_0_800.png    mnist_17_1450.png  mnist_2_450.png	 mnist_32_1100.png
# mnist_0_850.png    mnist_17_1500.png  mnist_24_50.png	 mnist_32_1150.png
# mnist_0_900.png    mnist_17_150.png   mnist_24_550.png	 mnist_32_1200.png
# mnist_0_950.png    mnist_17_1550.png  mnist_24_600.png	 mnist_32_1250.png
# mnist_10_0.png	   mnist_17_1600.png  mnist_24_650.png	 mnist_32_1300.png
# mnist_10_1000.png  mnist_17_1650.png  mnist_24_700.png	 mnist_32_1350.png
# mnist_10_100.png   mnist_17_1700.png  mnist_24_750.png	 mnist_32_1400.png
# mnist_10_1050.png  mnist_17_1750.png  mnist_24_800.png	 mnist_32_1450.png
# mnist_10_1100.png  mnist_17_1800.png  mnist_24_850.png	 mnist_32_1500.png
# mnist_10_1150.png  mnist_17_1850.png  mnist_24_900.png	 mnist_32_150.png
# mnist_10_1200.png  mnist_17_200.png   mnist_24_950.png	 mnist_32_1550.png
# mnist_10_1250.png  mnist_17_250.png   mnist_2_500.png	 mnist_32_1600.png
# mnist_10_1300.png  mnist_17_300.png   mnist_2_50.png	 mnist_32_1650.png
# mnist_10_1350.png  mnist_17_350.png   mnist_25_0.png	 mnist_32_1700.png
# mnist_10_1400.png  mnist_17_400.png   mnist_25_1000.png  mnist_32_1750.png
# mnist_10_1450.png  mnist_17_450.png   mnist_25_100.png	 mnist_32_1800.png
# mnist_10_1500.png  mnist_17_500.png   mnist_25_1050.png  mnist_32_1850.png
# mnist_10_150.png   mnist_1_750.png    mnist_25_1100.png  mnist_32_200.png
# mnist_10_1550.png  mnist_17_50.png    mnist_25_1150.png  mnist_32_250.png
# mnist_10_1600.png  mnist_17_550.png   mnist_25_1200.png  mnist_32_300.png
# mnist_10_1650.png  mnist_17_600.png   mnist_25_1250.png  mnist_32_350.png
# mnist_10_1700.png  mnist_17_650.png   mnist_25_1300.png  mnist_32_400.png
# mnist_10_1750.png  mnist_17_700.png   mnist_25_1350.png  mnist_32_450.png
# mnist_10_1800.png  mnist_17_750.png   mnist_25_1400.png  mnist_32_500.png
# mnist_10_1850.png  mnist_17_800.png   mnist_25_1450.png  mnist_3_250.png
# mnist_10_200.png   mnist_17_850.png   mnist_25_1500.png  mnist_32_50.png
# mnist_10_250.png   mnist_17_900.png   mnist_25_150.png	 mnist_32_550.png
# mnist_10_300.png   mnist_17_950.png   mnist_25_1550.png  mnist_32_600.png
# mnist_10_350.png   mnist_1_800.png    mnist_25_1600.png  mnist_32_650.png
# mnist_10_400.png   mnist_18_0.png     mnist_25_1650.png  mnist_32_700.png
# mnist_10_450.png   mnist_18_1000.png  mnist_25_1700.png  mnist_32_750.png
# mnist_10_500.png   mnist_18_100.png   mnist_25_1750.png  mnist_32_800.png
# mnist_10_50.png    mnist_18_1050.png  mnist_25_1800.png  mnist_32_850.png
# mnist_10_550.png   mnist_18_1100.png  mnist_25_1850.png  mnist_32_900.png
# mnist_10_600.png   mnist_18_1150.png  mnist_25_200.png	 mnist_32_950.png
# mnist_10_650.png   mnist_18_1200.png  mnist_25_250.png	 mnist_3_300.png
# mnist_10_700.png   mnist_18_1250.png  mnist_25_300.png	 mnist_33_0.png
# mnist_10_750.png   mnist_18_1300.png  mnist_25_350.png	 mnist_3_350.png
# mnist_10_800.png   mnist_18_1350.png  mnist_25_400.png	 mnist_3_400.png
# mnist_10_850.png   mnist_18_1400.png  mnist_25_450.png	 mnist_3_450.png
# mnist_10_900.png   mnist_18_1450.png  mnist_25_500.png	 mnist_3_500.png
# mnist_10_950.png   mnist_18_1500.png  mnist_2_550.png	 mnist_3_50.png
# mnist_1_0.png	   mnist_18_150.png   mnist_25_50.png	 mnist_3_550.png
# mnist_1_1000.png   mnist_18_1550.png  mnist_25_550.png	 mnist_3_600.png
# mnist_1_100.png    mnist_18_1600.png  mnist_25_600.png	 mnist_3_650.png
# mnist_1_1050.png   mnist_18_1650.png  mnist_25_650.png	 mnist_3_700.png
# mnist_11_0.png	   mnist_18_1700.png  mnist_25_700.png	 mnist_3_750.png
# mnist_11_1000.png  mnist_18_1750.png  mnist_25_750.png	 mnist_3_800.png
# mnist_1_1100.png   mnist_18_1800.png  mnist_25_800.png	 mnist_3_850.png
# mnist_11_100.png   mnist_18_1850.png  mnist_25_850.png	 mnist_3_900.png
# mnist_11_1050.png  mnist_18_200.png   mnist_25_900.png	 mnist_3_950.png
# mnist_11_1100.png  mnist_18_250.png   mnist_25_950.png	 mnist_4_0.png
# mnist_11_1150.png  mnist_18_300.png   mnist_2_600.png	 mnist_4_1000.png
# mnist_11_1200.png  mnist_18_350.png   mnist_26_0.png	 mnist_4_100.png
# mnist_11_1250.png  mnist_18_400.png   mnist_26_1000.png  mnist_4_1050.png
# mnist_11_1300.png  mnist_18_450.png   mnist_26_100.png	 mnist_4_1100.png
# mnist_11_1350.png  mnist_18_500.png   mnist_26_1050.png  mnist_4_1150.png
# mnist_11_1400.png  mnist_1_850.png    mnist_26_1100.png  mnist_4_1200.png
# mnist_11_1450.png  mnist_18_50.png    mnist_26_1150.png  mnist_4_1250.png
# mnist_11_1500.png  mnist_18_550.png   mnist_26_1200.png  mnist_4_1300.png
# mnist_1_1150.png   mnist_18_600.png   mnist_26_1250.png  mnist_4_1350.png
# mnist_11_150.png   mnist_18_650.png   mnist_26_1300.png  mnist_4_1400.png
# mnist_11_1550.png  mnist_18_700.png   mnist_26_1350.png  mnist_4_1450.png
# mnist_11_1600.png  mnist_18_750.png   mnist_26_1400.png  mnist_4_1500.png
# mnist_11_1650.png  mnist_18_800.png   mnist_26_1450.png  mnist_4_150.png
# mnist_11_1700.png  mnist_18_850.png   mnist_26_1500.png  mnist_4_1550.png
# mnist_11_1750.png  mnist_18_900.png   mnist_26_150.png	 mnist_4_1600.png
# mnist_11_1800.png  mnist_18_950.png   mnist_26_1550.png  mnist_4_1650.png
# mnist_11_1850.png  mnist_1_900.png    mnist_26_1600.png  mnist_4_1700.png
# mnist_1_1200.png   mnist_19_0.png     mnist_26_1650.png  mnist_4_1750.png
# mnist_11_200.png   mnist_19_1000.png  mnist_26_1700.png  mnist_4_1800.png
# mnist_1_1250.png   mnist_19_100.png   mnist_26_1750.png  mnist_4_1850.png
# mnist_11_250.png   mnist_19_1050.png  mnist_26_1800.png  mnist_4_200.png
# mnist_1_1300.png   mnist_19_1100.png  mnist_26_1850.png  mnist_4_250.png
# mnist_11_300.png   mnist_19_1150.png  mnist_26_200.png	 mnist_4_300.png
# mnist_1_1350.png   mnist_19_1200.png  mnist_26_250.png	 mnist_4_350.png
# mnist_11_350.png   mnist_19_1250.png  mnist_26_300.png	 mnist_4_400.png
# mnist_1_1400.png   mnist_19_1300.png  mnist_26_350.png	 mnist_4_450.png
# mnist_11_400.png   mnist_19_1350.png  mnist_26_400.png	 mnist_4_500.png
# mnist_1_1450.png   mnist_19_1400.png  mnist_26_450.png	 mnist_4_50.png
# mnist_11_450.png   mnist_19_1450.png  mnist_26_500.png	 mnist_4_550.png
# mnist_1_1500.png   mnist_19_1500.png  mnist_2_650.png	 mnist_4_600.png
# mnist_11_500.png   mnist_19_150.png   mnist_26_50.png	 mnist_4_650.png
# mnist_1_150.png    mnist_19_1550.png  mnist_26_550.png	 mnist_4_700.png
# mnist_11_50.png    mnist_19_1600.png  mnist_26_600.png	 mnist_4_750.png
# mnist_1_1550.png   mnist_19_1650.png  mnist_26_650.png	 mnist_4_800.png
# mnist_11_550.png   mnist_19_1700.png  mnist_26_700.png	 mnist_4_850.png
# mnist_1_1600.png   mnist_19_1750.png  mnist_26_750.png	 mnist_4_900.png
# mnist_11_600.png   mnist_19_1800.png  mnist_26_800.png	 mnist_4_950.png
# mnist_1_1650.png   mnist_19_1850.png  mnist_26_850.png	 mnist_5_0.png
# mnist_11_650.png   mnist_19_200.png   mnist_26_900.png	 mnist_5_1000.png
# mnist_1_1700.png   mnist_19_250.png   mnist_26_950.png	 mnist_5_100.png
# mnist_11_700.png   mnist_19_300.png   mnist_2_700.png	 mnist_5_1050.png
# mnist_1_1750.png   mnist_19_350.png   mnist_27_0.png	 mnist_5_1100.png
# mnist_11_750.png   mnist_19_400.png   mnist_27_1000.png  mnist_5_1150.png
# mnist_1_1800.png   mnist_19_450.png   mnist_27_100.png	 mnist_5_1200.png
# mnist_11_800.png   mnist_19_500.png   mnist_27_1050.png  mnist_5_1250.png
# mnist_1_1850.png   mnist_1_950.png    mnist_27_1100.png  mnist_5_1300.png
# mnist_11_850.png   mnist_19_50.png    mnist_27_1150.png  mnist_5_1350.png
# mnist_11_900.png   mnist_19_550.png   mnist_27_1200.png  mnist_5_1400.png
# mnist_11_950.png   mnist_19_600.png   mnist_27_1250.png  mnist_5_1450.png
# mnist_1_200.png    mnist_19_650.png   mnist_27_1300.png  mnist_5_1500.png
# mnist_12_0.png	   mnist_19_700.png   mnist_27_1350.png  mnist_5_150.png
# mnist_12_1000.png  mnist_19_750.png   mnist_27_1400.png  mnist_5_1550.png
# mnist_12_100.png   mnist_19_800.png   mnist_27_1450.png  mnist_5_1600.png
# mnist_12_1050.png  mnist_19_850.png   mnist_27_1500.png  mnist_5_1650.png
# mnist_12_1100.png  mnist_19_900.png   mnist_27_150.png	 mnist_5_1700.png
# mnist_12_1150.png  mnist_19_950.png   mnist_27_1550.png  mnist_5_1750.png
# mnist_12_1200.png  mnist_20_0.png     mnist_27_1600.png  mnist_5_1800.png
# mnist_12_1250.png  mnist_20_1000.png  mnist_27_1650.png  mnist_5_1850.png
# mnist_12_1300.png  mnist_20_100.png   mnist_27_1700.png  mnist_5_200.png
# mnist_12_1350.png  mnist_20_1050.png  mnist_27_1750.png  mnist_5_250.png
# mnist_12_1400.png  mnist_20_1100.png  mnist_27_1800.png  mnist_5_300.png
# mnist_12_1450.png  mnist_20_1150.png  mnist_27_1850.png  mnist_5_350.png
# mnist_12_1500.png  mnist_20_1200.png  mnist_27_200.png	 mnist_5_400.png
# mnist_12_150.png   mnist_20_1250.png  mnist_27_250.png	 mnist_5_450.png
# mnist_12_1550.png  mnist_20_1300.png  mnist_27_300.png	 mnist_5_500.png
# mnist_12_1600.png  mnist_20_1350.png  mnist_27_350.png	 mnist_5_50.png
# mnist_12_1650.png  mnist_20_1400.png  mnist_27_400.png	 mnist_5_550.png
# mnist_12_1700.png  mnist_20_1450.png  mnist_27_450.png	 mnist_5_600.png
# mnist_12_1750.png  mnist_20_1500.png  mnist_27_500.png	 mnist_5_650.png
# mnist_12_1800.png  mnist_20_150.png   mnist_2_750.png	 mnist_5_700.png
# mnist_12_1850.png  mnist_20_1550.png  mnist_27_50.png	 mnist_5_750.png
# mnist_12_200.png   mnist_20_1600.png  mnist_27_550.png	 mnist_5_800.png
# mnist_12_250.png   mnist_20_1650.png  mnist_27_600.png	 mnist_5_850.png
# mnist_12_300.png   mnist_20_1700.png  mnist_27_650.png	 mnist_5_900.png
# mnist_12_350.png   mnist_20_1750.png  mnist_27_700.png	 mnist_5_950.png
# mnist_12_400.png   mnist_20_1800.png  mnist_27_750.png	 mnist_6_0.png
# mnist_12_450.png   mnist_20_1850.png  mnist_27_800.png	 mnist_6_1000.png
# mnist_12_500.png   mnist_20_200.png   mnist_27_850.png	 mnist_6_100.png
# mnist_1_250.png    mnist_20_250.png   mnist_27_900.png	 mnist_6_1050.png
# mnist_12_50.png    mnist_20_300.png   mnist_27_950.png	 mnist_6_1100.png
# mnist_12_550.png   mnist_20_350.png   mnist_2_800.png	 mnist_6_1150.png
# mnist_12_600.png   mnist_20_400.png   mnist_28_0.png	 mnist_6_1200.png
# mnist_12_650.png   mnist_20_450.png   mnist_28_1000.png  mnist_6_1250.png
# mnist_12_700.png   mnist_20_500.png   mnist_28_100.png	 mnist_6_1300.png
# mnist_12_750.png   mnist_20_50.png    mnist_28_1050.png  mnist_6_1350.png
# mnist_12_800.png   mnist_20_550.png   mnist_28_1100.png  mnist_6_1400.png
# mnist_12_850.png   mnist_20_600.png   mnist_28_1150.png  mnist_6_1450.png
# mnist_12_900.png   mnist_20_650.png   mnist_28_1200.png  mnist_6_1500.png
# mnist_12_950.png   mnist_20_700.png   mnist_28_1250.png  mnist_6_150.png
# mnist_1_300.png    mnist_20_750.png   mnist_28_1300.png  mnist_6_1550.png
# mnist_13_0.png	   mnist_20_800.png   mnist_28_1350.png  mnist_6_1600.png
# mnist_13_1000.png  mnist_20_850.png   mnist_28_1400.png  mnist_6_1650.png
# mnist_13_100.png   mnist_20_900.png   mnist_28_1450.png  mnist_6_1700.png
# mnist_13_1050.png  mnist_20_950.png   mnist_28_1500.png  mnist_6_1750.png
# mnist_13_1100.png  mnist_2_0.png      mnist_28_150.png	 mnist_6_1800.png
# mnist_13_1150.png  mnist_2_1000.png   mnist_28_1550.png  mnist_6_1850.png
# mnist_13_1200.png  mnist_2_100.png    mnist_28_1600.png  mnist_6_200.png
# mnist_13_1250.png  mnist_2_1050.png   mnist_28_1650.png  mnist_6_250.png
# mnist_13_1300.png  mnist_21_0.png     mnist_28_1700.png  mnist_6_300.png
# mnist_13_1350.png  mnist_21_1000.png  mnist_28_1750.png  mnist_6_350.png
# mnist_13_1400.png  mnist_2_1100.png   mnist_28_1800.png  mnist_6_400.png
# mnist_13_1450.png  mnist_21_100.png   mnist_28_1850.png  mnist_6_450.png
# mnist_13_1500.png  mnist_21_1050.png  mnist_28_200.png	 mnist_6_500.png
# mnist_13_150.png   mnist_21_1100.png  mnist_28_250.png	 mnist_6_50.png
# mnist_13_1550.png  mnist_21_1150.png  mnist_28_300.png	 mnist_6_550.png
# mnist_13_1600.png  mnist_21_1200.png  mnist_28_350.png	 mnist_6_600.png
# mnist_13_1650.png  mnist_21_1250.png  mnist_28_400.png	 mnist_6_650.png
# mnist_13_1700.png  mnist_21_1300.png  mnist_28_450.png	 mnist_6_700.png
# mnist_13_1750.png  mnist_21_1350.png  mnist_28_500.png	 mnist_6_750.png
# mnist_13_1800.png  mnist_21_1400.png  mnist_2_850.png	 mnist_6_800.png
# mnist_13_1850.png  mnist_21_1450.png  mnist_28_50.png	 mnist_6_850.png
# mnist_13_200.png   mnist_21_1500.png  mnist_28_550.png	 mnist_6_900.png
# mnist_13_250.png   mnist_2_1150.png   mnist_28_600.png	 mnist_6_950.png
# mnist_13_300.png   mnist_21_150.png   mnist_28_650.png	 mnist_7_0.png
# mnist_13_350.png   mnist_21_1550.png  mnist_28_700.png	 mnist_7_1000.png
# mnist_13_400.png   mnist_21_1600.png  mnist_28_750.png	 mnist_7_100.png
# mnist_13_450.png   mnist_21_1650.png  mnist_28_800.png	 mnist_7_1050.png
# mnist_13_500.png   mnist_21_1700.png  mnist_28_850.png	 mnist_7_1100.png
# mnist_1_350.png    mnist_21_1750.png  mnist_28_900.png	 mnist_7_1150.png
# mnist_13_50.png    mnist_21_1800.png  mnist_28_950.png	 mnist_7_1200.png
# mnist_13_550.png   mnist_21_1850.png  mnist_2_900.png	 mnist_7_1250.png
# mnist_13_600.png   mnist_2_1200.png   mnist_29_0.png	 mnist_7_1300.png
# mnist_13_650.png   mnist_21_200.png   mnist_29_1000.png  mnist_7_1350.png
# mnist_13_700.png   mnist_2_1250.png   mnist_29_100.png	 mnist_7_1400.png
# mnist_13_750.png   mnist_21_250.png   mnist_29_1050.png  mnist_7_1450.png
# mnist_13_800.png   mnist_2_1300.png   mnist_29_1100.png  mnist_7_1500.png
# mnist_13_850.png   mnist_21_300.png   mnist_29_1150.png  mnist_7_150.png
# mnist_13_900.png   mnist_2_1350.png   mnist_29_1200.png  mnist_7_1550.png
# mnist_13_950.png   mnist_21_350.png   mnist_29_1250.png  mnist_7_1600.png
# mnist_1_400.png    mnist_2_1400.png   mnist_29_1300.png  mnist_7_1650.png
# mnist_14_0.png	   mnist_21_400.png   mnist_29_1350.png  mnist_7_1700.png
# mnist_14_1000.png  mnist_2_1450.png   mnist_29_1400.png  mnist_7_1750.png
# mnist_14_100.png   mnist_21_450.png   mnist_29_1450.png  mnist_7_1800.png
# mnist_14_1050.png  mnist_2_1500.png   mnist_29_1500.png  mnist_7_1850.png
# mnist_14_1100.png  mnist_21_500.png   mnist_29_150.png	 mnist_7_200.png
# mnist_14_1150.png  mnist_2_150.png    mnist_29_1550.png  mnist_7_250.png
# mnist_14_1200.png  mnist_21_50.png    mnist_29_1600.png  mnist_7_300.png
# mnist_14_1250.png  mnist_2_1550.png   mnist_29_1650.png  mnist_7_350.png
# mnist_14_1300.png  mnist_21_550.png   mnist_29_1700.png  mnist_7_400.png
# mnist_14_1350.png  mnist_2_1600.png   mnist_29_1750.png  mnist_7_450.png
# mnist_14_1400.png  mnist_21_600.png   mnist_29_1800.png  mnist_7_500.png
# mnist_14_1450.png  mnist_2_1650.png   mnist_29_1850.png  mnist_7_50.png
# mnist_14_1500.png  mnist_21_650.png   mnist_29_200.png	 mnist_7_550.png
# mnist_14_150.png   mnist_2_1700.png   mnist_29_250.png	 mnist_7_600.png
# mnist_14_1550.png  mnist_21_700.png   mnist_29_300.png	 mnist_7_650.png
# mnist_14_1600.png  mnist_2_1750.png   mnist_29_350.png	 mnist_7_700.png
# mnist_14_1650.png  mnist_21_750.png   mnist_29_400.png	 mnist_7_750.png
# mnist_14_1700.png  mnist_2_1800.png   mnist_29_450.png	 mnist_7_800.png
# mnist_14_1750.png  mnist_21_800.png   mnist_29_500.png	 mnist_7_850.png
# mnist_14_1800.png  mnist_2_1850.png   mnist_2_950.png	 mnist_7_900.png
# mnist_14_1850.png  mnist_21_850.png   mnist_29_50.png	 mnist_7_950.png
# mnist_14_200.png   mnist_21_900.png   mnist_29_550.png	 mnist_8_0.png
# mnist_14_250.png   mnist_21_950.png   mnist_29_600.png	 mnist_8_1000.png
# mnist_14_300.png   mnist_2_200.png    mnist_29_650.png	 mnist_8_100.png
# mnist_14_350.png   mnist_22_0.png     mnist_29_700.png	 mnist_8_1050.png
# mnist_14_400.png   mnist_22_1000.png  mnist_29_750.png	 mnist_8_1100.png
# mnist_14_450.png   mnist_22_100.png   mnist_29_800.png	 mnist_8_1150.png
# mnist_14_500.png   mnist_22_1050.png  mnist_29_850.png	 mnist_8_1200.png
# mnist_1_450.png    mnist_22_1100.png  mnist_29_900.png	 mnist_8_1250.png
# mnist_14_50.png    mnist_22_1150.png  mnist_29_950.png	 mnist_8_1300.png
# mnist_14_550.png   mnist_22_1200.png  mnist_30_0.png	 mnist_8_1350.png
# mnist_14_600.png   mnist_22_1250.png  mnist_30_1000.png  mnist_8_1400.png
# mnist_14_650.png   mnist_22_1300.png  mnist_30_100.png	 mnist_8_1450.png
# mnist_14_700.png   mnist_22_1350.png  mnist_30_1050.png  mnist_8_1500.png
# mnist_14_750.png   mnist_22_1400.png  mnist_30_1100.png  mnist_8_150.png
# mnist_14_800.png   mnist_22_1450.png  mnist_30_1150.png  mnist_8_1550.png
# mnist_14_850.png   mnist_22_1500.png  mnist_30_1200.png  mnist_8_1600.png
# mnist_14_900.png   mnist_22_150.png   mnist_30_1250.png  mnist_8_1650.png
# mnist_14_950.png   mnist_22_1550.png  mnist_30_1300.png  mnist_8_1700.png
# mnist_1_500.png    mnist_22_1600.png  mnist_30_1350.png  mnist_8_1750.png
# mnist_1_50.png	   mnist_22_1650.png  mnist_30_1400.png  mnist_8_1800.png
# mnist_15_0.png	   mnist_22_1700.png  mnist_30_1450.png  mnist_8_1850.png
# mnist_15_1000.png  mnist_22_1750.png  mnist_30_1500.png  mnist_8_200.png
# mnist_15_100.png   mnist_22_1800.png  mnist_30_150.png	 mnist_8_250.png
# mnist_15_1050.png  mnist_22_1850.png  mnist_30_1550.png  mnist_8_300.png
# mnist_15_1100.png  mnist_22_200.png   mnist_30_1600.png  mnist_8_350.png
# mnist_15_1150.png  mnist_22_250.png   mnist_30_1650.png  mnist_8_400.png
# mnist_15_1200.png  mnist_22_300.png   mnist_30_1700.png  mnist_8_450.png
# mnist_15_1250.png  mnist_22_350.png   mnist_30_1750.png  mnist_8_500.png
# mnist_15_1300.png  mnist_22_400.png   mnist_30_1800.png  mnist_8_50.png
# mnist_15_1350.png  mnist_22_450.png   mnist_30_1850.png  mnist_8_550.png
# mnist_15_1400.png  mnist_22_500.png   mnist_30_200.png	 mnist_8_600.png
# mnist_15_1450.png  mnist_2_250.png    mnist_30_250.png	 mnist_8_650.png
# mnist_15_1500.png  mnist_22_50.png    mnist_30_300.png	 mnist_8_700.png
# mnist_15_150.png   mnist_22_550.png   mnist_30_350.png	 mnist_8_750.png
# mnist_15_1550.png  mnist_22_600.png   mnist_30_400.png	 mnist_8_800.png
# mnist_15_1600.png  mnist_22_650.png   mnist_30_450.png	 mnist_8_850.png
# mnist_15_1650.png  mnist_22_700.png   mnist_30_500.png	 mnist_8_900.png
# mnist_15_1700.png  mnist_22_750.png   mnist_30_50.png	 mnist_8_950.png
# mnist_15_1750.png  mnist_22_800.png   mnist_30_550.png	 mnist_9_0.png
# mnist_15_1800.png  mnist_22_850.png   mnist_30_600.png	 mnist_9_1000.png
# mnist_15_1850.png  mnist_22_900.png   mnist_30_650.png	 mnist_9_100.png
# mnist_15_200.png   mnist_22_950.png   mnist_30_700.png	 mnist_9_1050.png
# mnist_15_250.png   mnist_2_300.png    mnist_30_750.png	 mnist_9_1100.png
# mnist_15_300.png   mnist_23_0.png     mnist_30_800.png	 mnist_9_1150.png
# mnist_15_350.png   mnist_23_1000.png  mnist_30_850.png	 mnist_9_1200.png
# mnist_15_400.png   mnist_23_100.png   mnist_30_900.png	 mnist_9_1250.png
# mnist_15_450.png   mnist_23_1050.png  mnist_30_950.png	 mnist_9_1300.png
# mnist_15_500.png   mnist_23_1100.png  mnist_3_0.png	 mnist_9_1350.png
# mnist_1_550.png    mnist_23_1150.png  mnist_3_1000.png	 mnist_9_1400.png
# mnist_15_50.png    mnist_23_1200.png  mnist_3_100.png	 mnist_9_1450.png
# mnist_15_550.png   mnist_23_1250.png  mnist_3_1050.png	 mnist_9_1500.png
# mnist_15_600.png   mnist_23_1300.png  mnist_31_0.png	 mnist_9_150.png
# mnist_15_650.png   mnist_23_1350.png  mnist_31_1000.png  mnist_9_1550.png
# mnist_15_700.png   mnist_23_1400.png  mnist_3_1100.png	 mnist_9_1600.png
# mnist_15_750.png   mnist_23_1450.png  mnist_31_100.png	 mnist_9_1650.png
# mnist_15_800.png   mnist_23_1500.png  mnist_31_1050.png  mnist_9_1700.png
# mnist_15_850.png   mnist_23_150.png   mnist_31_1100.png  mnist_9_1750.png
# mnist_15_900.png   mnist_23_1550.png  mnist_31_1150.png  mnist_9_1800.png
# mnist_15_950.png   mnist_23_1600.png  mnist_31_1200.png  mnist_9_1850.png
# mnist_1_600.png    mnist_23_1650.png  mnist_31_1250.png  mnist_9_200.png
# mnist_16_0.png	   mnist_23_1700.png  mnist_31_1300.png  mnist_9_250.png
# mnist_16_1000.png  mnist_23_1750.png  mnist_31_1350.png  mnist_9_300.png
# mnist_16_100.png   mnist_23_1800.png  mnist_31_1400.png  mnist_9_350.png
# mnist_16_1050.png  mnist_23_1850.png  mnist_31_1450.png  mnist_9_400.png
# mnist_16_1100.png  mnist_23_200.png   mnist_31_1500.png  mnist_9_450.png
# mnist_16_1150.png  mnist_23_250.png   mnist_3_1150.png	 mnist_9_500.png
# mnist_16_1200.png  mnist_23_300.png   mnist_31_150.png	 mnist_9_50.png
# mnist_16_1250.png  mnist_23_350.png   mnist_31_1550.png  mnist_9_550.png
# mnist_16_1300.png  mnist_23_400.png   mnist_31_1600.png  mnist_9_600.png
# mnist_16_1350.png  mnist_23_450.png   mnist_31_1650.png  mnist_9_650.png
# mnist_16_1400.png  mnist_23_500.png   mnist_31_1700.png  mnist_9_700.png
# mnist_16_1450.png  mnist_2_350.png    mnist_31_1750.png  mnist_9_750.png
# mnist_16_1500.png  mnist_23_50.png    mnist_31_1800.png  mnist_9_800.png
# mnist_16_150.png   mnist_23_550.png   mnist_31_1850.png  mnist_9_850.png
# mnist_16_1550.png  mnist_23_600.png   mnist_3_1200.png	 mnist_9_900.png
# mnist_16_1600.png  mnist_23_650.png   mnist_31_200.png	 mnist_9_950.png
# mnist_16_1650.png  mnist_23_700.png   mnist_3_1250.png
